# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {
    "Model": ["Logistic Regression", "Random Forest", "SVM", "Bayesian - Multivariate", 
              "Bayesian - Naive", "Bayesian - Nonparametric"],
    "none + none": [0.5912, 0.9579, 0.5910, 0.5738, 0.8836, 0.4484],
    "none + pca": [0.5347, 0.5544, 0.5893, 0.5626, 0.5846, 0.4113],
    "none + sffs": [1.0000, 0.9963, 0.8121, 0.9970, 0.8712, 0.9995],
    "minmax + none": [0.9727, 0.9561, 0.9748, 0.9712, 0.8806, 0.5869],
    "minmax + pca": [0.5881, 0.5355, 0.5850, 0.5782, 0.5881, 0.5907],
    "minmax + sffs": [1.0000, 0.9983, 0.9992, 0.9971, 0.9202, 0.5894],
    "zscore + none": [1.0000, 0.9583, 0.9890, 0.9736, 0.8803, 0.8491],
    "zscore + pca": [0.6019, 0.5947, 0.4802, 0.7247, 0.6030, 0.4872],
    "zscore + sffs": [1.0000, 0.9981, 0.9989, 0.9964, 0.8404, 0.8664]
}

df = pd.DataFrame(data)
df.set_index("Model", inplace=True)

plt.figure(figsize=(40, 30))
df.plot(kind='bar', figsize=(20, 8), rot=45)
plt.ylabel("Mean Accuracy")
plt.title("Model Accuracy Comparison by Normalization + Reduction Techniques")
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.legend(title="Technique Combination", bbox_to_anchor=(1.02, 1), loc='upper left')
plt.tight_layout()
plt.show()
